# %%
import pandas as pd
import pandas.io.data as wb
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
from datetime import datetime
start = datetime(2016,6,1)
end = datetime(2016,12,1)
data = wb.DataReader("^N225","yahoo",start)

# %%
data225 = data["Adj Close"]
data225.plot()

# %%
data225_np = np.log(data225)
data225_np.plot()
